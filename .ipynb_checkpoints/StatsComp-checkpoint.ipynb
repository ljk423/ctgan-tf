# %%
import torch
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib

# %%
t_stats = joblib.load('torch.stats')
tf_stats = joblib.load('tf.stats')

# %%
np.array(tf_stats[0]).shape
# Out:
# (325, 4)

# %%
df = pd.DataFrame(np.concatenate([t_stats[0], tf_stats[0]], axis=1), 
                  columns=['torch_d_loss', 'torch_gp', 'torch_g_loss', 'torch_ce', 
                           'tf_d_loss', 'tf_gp', 'tf_g_loss', 'tf_ce'])

# %%
df.head(10)
# Out:
#    torch_d_loss  torch_gp  torch_g_loss  torch_ce  tf_d_loss     tf_gp  \
# 0      0.033351  6.380336      2.169417  2.144826   0.003268  6.475719
# 1     -0.009531  6.192698      2.042189  1.993765  -0.002958  6.291580
# 2     -0.032577  6.023102      2.181266  2.137733  -0.051934  6.291409
# 3     -0.047341  5.838293      2.111396  2.047565  -0.077248  6.034697
# 4     -0.099431  5.648075      2.105368  2.017583  -0.112880  5.915508
# 5     -0.121348  5.378503      2.072782  2.002740  -0.158668  5.563335
# 6     -0.167558  4.982900      2.145970  2.035390  -0.181769  5.063369
# 7     -0.209994  4.579516      2.119257  2.009888  -0.235533  4.881959
# 8     -0.283037  4.134391      2.125734  1.998410  -0.316553  4.327384
# 9     -0.325714  3.665493      2.178635  2.055735  -0.373013  3.967247
#
#    tf_g_loss     tf_ce
# 0   2.134315  2.096640
# 1   2.108020  2.072767
# 2   2.116381  2.069084
# 3   2.093448  2.041565
# 4   2.142265  2.065087
# 5   2.096985  2.027533
# 6   2.082226  2.015700
# 7   2.132007  2.035581
# 8   2.111367  1.983311
# 9   2.167431  2.027856

# %%
df.iloc[:,:4].plot(figsize=(20,10))

# %%
df.iloc[:,4:].plot(figsize=(20,10))

# %%
df.plot(figsize=(20,10))

# %%
t_cols = list()
f = 'tf_'
models = ['d_', 'g_']
for i in range(len(models)):
    m = models[i]
    for l in range(len(t_stats[i+1][0])//2):
        t_cols.append(f + m + str(l) + '_w')
        t_cols.append(f + m + str(l) + '_b')
t_cols
# Out:
# ['tf_d_0_w',
#  'tf_d_0_b',
#  'tf_d_1_w',
#  'tf_d_1_b',
#  'tf_d_2_w',
#  'tf_d_2_b',
#  'tf_g_0_w',
#  'tf_g_0_b',
#  'tf_g_1_w',
#  'tf_g_1_b',
#  'tf_g_2_w',
#  'tf_g_2_b',
#  'tf_g_3_w',
#  'tf_g_3_b',
#  'tf_g_4_w',
#  'tf_g_4_b']

# %%
tf_cols = list()
f = 'tf_'
models = ['d_', 'g_']
for i in range(len(models)):
    m = models[i]
    for l in range(len(tf_stats[i+1][0])//2):
        tf_cols.append(f + m + str(l) + '_w')
        tf_cols.append(f + m + str(l) + '_b')
tf_cols
# Out:
# ['tf_d_0_w',
#  'tf_d_0_b',
#  'tf_d_1_w',
#  'tf_d_1_b',
#  'tf_d_2_w',
#  'tf_d_2_b',
#  'tf_g_0_w',
#  'tf_g_0_b',
#  'tf_g_1_w',
#  'tf_g_1_b',
#  'tf_g_2_w',
#  'tf_g_2_b',
#  'tf_g_3_w',
#  'tf_g_3_b',
#  'tf_g_4_w',
#  'tf_g_4_b']

# %%
grads = pd.DataFrame(np.concatenate([t_stats[1], t_stats[2], tf_stats[1], tf_stats[2]], axis=1), 
                     columns=t_cols + tf_cols)

# %%
grads.head()
# Out:
#    tf_d_0_w  tf_d_0_b  tf_d_1_w  tf_d_1_b  tf_d_2_w  tf_d_2_b      tf_g_0_w  \
# 0  0.000016  0.000322 -0.000087  0.001093  0.075650       0.0 -2.282903e-06
# 1 -0.000012 -0.000095 -0.000188 -0.000358  0.085049       0.0 -6.329843e-06
# 2 -0.000009 -0.000087 -0.000147 -0.000533  0.068923       0.0  3.958933e-07
# 3 -0.000032 -0.000391 -0.000223 -0.000812  0.081918       0.0 -6.237015e-06
# 4 -0.000091 -0.001395 -0.000211 -0.002180  0.068272       0.0  5.376803e-06
#
#        tf_g_0_b  tf_g_1_w  tf_g_1_b      tf_g_2_w      tf_g_2_b  tf_g_3_w  \
# 0  2.164981e-11  0.000220  0.000154 -6.846281e-07  1.804525e-11  0.000208
# 1 -3.719959e-11  0.000062  0.000024 -5.585489e-06 -2.994303e-11  0.000148
# 2 -3.660357e-11  0.000079  0.000078  2.129132e-06 -1.286002e-11  0.000077
# 3  1.701711e-11  0.000166  0.000127 -3.569516e-07  1.430013e-11  0.000100
# 4  4.400900e-12  0.000127  0.000028 -5.200316e-06 -1.482126e-11  0.000086
#
#    tf_g_3_b      tf_g_4_w  tf_g_4_b  tf_d_0_w  tf_d_0_b  tf_d_1_w  tf_d_1_b  \
# 0  0.000223  6.856718e-08 -0.000004  0.000005  0.000109 -0.000139  0.000269
# 1  0.000122 -5.456991e-06 -0.000018 -0.000020 -0.000311 -0.000132  0.000003
# 2  0.000041 -4.883123e-06 -0.000017 -0.000034 -0.000564 -0.000098 -0.001146
# 3  0.000059 -7.008757e-06 -0.000019 -0.000070 -0.001100 -0.000203 -0.002175
# 4  0.000006 -5.556666e-06 -0.000019 -0.000085 -0.001410 -0.000169 -0.002300
#
#    tf_d_2_w  tf_d_2_b  tf_g_0_w      tf_g_0_b  tf_g_1_w  tf_g_1_b  \
# 0  0.046019       0.0  0.000003  6.441357e-10  0.000154  0.000098
# 1  0.058319       0.0  0.000001  6.482068e-10  0.000041  0.000006
# 2  0.018756       0.0  0.000006  5.964517e-10  0.000045  0.000054
# 3  0.013985       0.0 -0.000007  6.017925e-10  0.000082  0.000015
# 4  0.008799       0.0  0.000004  6.467673e-10  0.000054  0.000020
#
#        tf_g_2_w      tf_g_2_b  tf_g_3_w      tf_g_3_b  tf_g_4_w  tf_g_4_b
# 0 -1.752217e-06 -6.030279e-09  0.000142  9.578871e-05  0.000004  0.000018
# 1 -1.863637e-06 -5.943561e-09  0.000129  8.048454e-05 -0.000001 -0.000002
# 2  4.538326e-07 -6.026212e-09  0.000065  9.762844e-07 -0.000013 -0.000046
# 3  2.034133e-06 -6.010306e-09  0.000045 -5.550388e-05 -0.000027 -0.000099
# 4  1.843343e-06 -5.929151e-09  0.000061  1.486150e-05 -0.000043 -0.000156

# %%
grads.iloc[:,:len(t_cols)].plot(figsize=(20,10))

# %%
grads.iloc[:,len(t_cols):].plot(figsize=(20,10))

# %%
grads.plot(figsize=(20,10))

# %%
weights = pd.DataFrame(np.concatenate([t_stats[3], t_stats[4], tf_stats[3], tf_stats[4]], axis=1), 
                       columns=t_cols + tf_cols)

# %%
weights.head()
# Out:
#    tf_d_0_w  tf_d_0_b  tf_d_1_w  tf_d_1_b  tf_d_2_w  tf_d_2_b  tf_g_0_w  \
# 0  0.000029 -0.000592  0.000092  0.001607 -0.003142  0.024859 -0.000135
# 1  0.000029 -0.000603  0.000093  0.001588 -0.003172  0.024859 -0.000134
# 2  0.000029 -0.000599  0.000095  0.001586 -0.003198  0.024859 -0.000134
# 3  0.000030 -0.000602  0.000096  0.001592 -0.003222  0.024859 -0.000134
# 4  0.000031 -0.000599  0.000098  0.001607 -0.003250  0.024859 -0.000134
#
#    tf_g_0_b  tf_g_1_w  tf_g_1_b  tf_g_2_w  tf_g_2_b  tf_g_3_w  tf_g_3_b  \
# 0  0.001253  1.000000  0.000000  0.000021  0.000191  1.000000  0.000000
# 1  0.001252  0.999966 -0.000016  0.000022  0.000189  0.999963 -0.000034
# 2  0.001251  0.999945 -0.000026  0.000023  0.000188  0.999925 -0.000064
# 3  0.001251  0.999928 -0.000037  0.000023  0.000187  0.999899 -0.000079
# 4  0.001250  0.999892 -0.000062  0.000023  0.000185  0.999875 -0.000093
#
#    tf_g_4_w  tf_g_4_b  tf_d_0_w  tf_d_0_b  tf_d_1_w  tf_d_1_b  tf_d_2_w  \
# 0  0.000027 -0.001683  0.000009 -0.002384 -0.000071 -0.002369 -0.003555
# 1  0.000007 -0.001697  0.000009 -0.002384 -0.000070 -0.002365 -0.003582
# 2 -0.000012 -0.001712  0.000009 -0.002371 -0.000070 -0.002359 -0.003605
# 3 -0.000027 -0.001725  0.000010 -0.002352 -0.000070 -0.002340 -0.003621
# 4 -0.000042 -0.001738  0.000012 -0.002326 -0.000069 -0.002303 -0.003635
#
#    tf_d_2_b  tf_g_0_w  tf_g_0_b  tf_g_1_w  tf_g_1_b  tf_g_2_w  tf_g_2_b  \
# 0 -0.000889 -0.000175  0.000629  1.000000  0.000000 -0.000083 -0.006009
# 1 -0.000889 -0.000175  0.000629  0.999981 -0.000014 -0.000083 -0.005995
# 2 -0.000889 -0.000176  0.000631  0.999966 -0.000023 -0.000083 -0.005979
# 3 -0.000889 -0.000176  0.000632  0.999949 -0.000033 -0.000083 -0.005963
# 4 -0.000889 -0.000177  0.000634  0.999931 -0.000034 -0.000083 -0.005947
#
#    tf_g_3_w  tf_g_3_b  tf_g_4_w  tf_g_4_b
# 0  1.000000  0.000000  0.000068  0.000171
# 1  0.999978 -0.000030  0.000048  0.000159
# 2  0.999948 -0.000047  0.000030  0.000138
# 3  0.999925 -0.000053  0.000013  0.000118
# 4  0.999912 -0.000050 -0.000003  0.000103

# %%
weights.iloc[:,:len(t_cols)].plot(figsize=(20,10))

# %%
weights.iloc[:,len(t_cols):].plot(figsize=(20,10))

# %%
weights.plot(figsize=(20,10))

# %%
for i in range(50):
    print(torch.zeros(1).uniform_(-1, 1))
# Out:
# tensor([-0.8505])
# tensor([0.2445])
# tensor([-0.9784])
# tensor([0.2136])
# tensor([-0.8949])
# tensor([-0.5089])
# tensor([-0.6299])
# tensor([-0.4478])
# tensor([0.8384])
# tensor([0.9100])
# tensor([-0.4707])
# tensor([-0.4772])
# tensor([-0.5254])
# tensor([-0.1803])
# tensor([0.0028])
# tensor([-0.7644])
# tensor([0.5039])
# tensor([-0.8002])
# tensor([-0.1850])
# tensor([0.3453])
# tensor([0.9769])
# tensor([-0.2227])
# tensor([0.5694])
# tensor([-0.8854])
# tensor([0.3261])
# tensor([-0.2221])
# tensor([-0.8017])
# tensor([-0.4808])
# tensor([-0.8213])
# tensor([-0.3006])
# tensor([-0.2429])
# tensor([-0.4694])
# tensor([0.7992])
# tensor([-0.8579])
# tensor([0.5560])
# tensor([0.3379])
# tensor([0.0221])
# tensor([-0.7086])
# tensor([0.0664])
# tensor([0.8110])
# tensor([0.1572])
# tensor([-0.6779])
# tensor([0.8432])
# tensor([-0.3325])
# tensor([-0.5501])
# tensor([0.9420])
# tensor([0.7666])
# tensor([0.9967])
# tensor([0.8554])
# tensor([-0.5251])

# %%
x = torch.zeros(10, 1)

# %%
def _calculate_fan_in_and_fan_out(tensor):
    dimensions = tensor.dim()
    if dimensions < 2:
        raise ValueError("Fan in and fan out can not be computed for tensor with fewer than 2 dimensions")

    num_input_fmaps = tensor.size(1)
    num_output_fmaps = tensor.size(0)
    receptive_field_size = 1
    if tensor.dim() > 2:
        receptive_field_size = tensor[0][0].numel()
    fan_in = num_input_fmaps * receptive_field_size
    fan_out = num_output_fmaps * receptive_field_size

    return fan_in, fan_out

# %%
_calculate_fan_in_and_fan_out(x)
# Out:
# (1, 10)
